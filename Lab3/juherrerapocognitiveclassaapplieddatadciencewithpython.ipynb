# %% [markdown]
# <a href="https://colab.research.google.com/github/FelipeH22/MetNumUN2023I/blob/main/Lab3/juherrerapocognitiveclassaapplieddatadciencewithpython.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# [linkedin.com/in/felipe-herrera-3654a8269](https://www.linkedin.com/in/felipe-herrera-3654a8269)

# %% [markdown]
# ![linkedin.png](data:image/png;base64,...)

# %% [markdown]
# ![Python101ForDataScience.png](data:image/png;base64,...)

# %% [markdown]
# ![DataVisualizationWithPython.png](data:image/png;base64,...)

# %% [markdown]
# ![DataAnalysisWithPython.png](data:image/png;base64,...)
